# %%
"""
WE'RE LEARNING PYTHON -- DAY 2! -- PART 2!
"""
# Out:
# "\nWE'RE LEARNING PYTHON -- DAY 2! -- PART 2!\n"

# %%
"""
ANNOTATING TEXT PROGRAMMATICALLY
"""
# Out:
# '\nANNOTATING TEXT PROGRAMMATICALLY\n'

# %%
# Import the sys package so we can import NLTK 
# (Natural Language ToolKit).
import sys

# %%
# !{sys.executable} -m pip install nltk

# %%
# Import the NLTK downloader for packages.
import nltk.downloader
nltk.download('averaged_perceptron_tagger') # For POS tagger.
nltk.download('punkt') # For word tokenizer.
nltk.download('tagsets') # For UPenn tagset help.
nltk.download('wordnet') # For WordNet lemmatizer.
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\clair\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\clair\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package tagsets to
# [nltk_data]     C:\Users\clair\AppData\Roaming\nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\clair\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Import the NLTK tokenize function (for words).
from nltk.tokenize import word_tokenize

# %%
# Tokenize a sample sentence. Thanks for the sentence Charlie!
essential_text = "We definitely want to remember the way in which communities need agency over their own histories!"
tokenized_text = word_tokenize(essential_text)
print(tokenized_text)
# Out:
# ['We', 'definitely', 'want', 'to', 'remember', 'the', 'way', 'in', 'which', 'communities', 'need', 'agency', 'over', 'their', 'own', 'histories', '!']

# %%
# Use the NLTK POS (Part Of Speech) tagger on the tokenized
# sentence.
from nltk import pos_tag
pos_tag(tokenized_text)
# Out:
# [('We', 'PRP'),
#  ('definitely', 'RB'),
#  ('want', 'VBP'),
#  ('to', 'TO'),
#  ('remember', 'VB'),
#  ('the', 'DT'),
#  ('way', 'NN'),
#  ('in', 'IN'),
#  ('which', 'WDT'),
#  ('communities', 'NNS'),
#  ('need', 'VBP'),
#  ('agency', 'NN'),
#  ('over', 'IN'),
#  ('their', 'PRP$'),
#  ('own', 'JJ'),
#  ('histories', 'NNS'),
#  ('!', '.')]

# %%
# What do these abbreviations all mean?
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
# ...

# %%
# We can also do this using the spaCy package!
#!{sys.executable} -m pip install spaCy

# If we want to make sure we install a specific version
# we can use this:
# !{sys.executable} -m pip install spaCy==2.3.2

# You can also use this:
# `!{sys.executable} -m pip install spaCy --use-feature=2020-resolver`

# %%
# Download our neural network English core model.
# !{sys.executable} -m spacy download en_core_web_sm
# Out:
# ...
# [+] Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
# If this block doesn't run, run
# `{sys.executable} -m spacy download en`
# and then re-run!
import en_core_web_sm
import spacy as sp

# Load the English core model.
nlp = en_core_web_sm.load()

# %%
# Load our previous sentence as a spaCy object.
spacy_sen = nlp(essential_text)

# %%
# Print the sentence text.
print(spacy_sen.text)
# Out:
# We definitely want to remember the way in which communities need agency over their own histories!

# %%
# We can print individual parts of speech like this:
print(spacy_sen[4].text + " : " + spacy_sen[4].pos_)
# Out:
# remember : VERB

# %%
# Or all of them like this:
for word in spacy_sen:
    print(word.text + " : " + word.pos_)
# Out:
# We : PRON
# definitely : ADV
# want : VERB
# to : PART
# remember : VERB
# the : DET
# way : NOUN
# in : ADP
# which : DET
# communities : NOUN
# need : VERB
# agency : NOUN
# over : ADP
# their : DET
# own : ADJ
# histories : NOUN
# ! : PUNCT

# %%
# We can even go more in-depth using the 'explain' parameter:
print(spacy_sen[4].text + " : " + sp.explain(spacy_sen[4].tag_))
# Out:
# remember : verb, base form

# %%
# But words also have explicit relationships to one another.
# Let's visualize them!
from spacy import displacy

displacy.render(spacy_sen, style='dep', jupyter=True, options={'distance': 85})

# If you aren't using Jupyter, you'll need to use:
#
# `displacy.serve(spacy_sen, style='dep', options={'distance': 120})
#
# Then you'll see the following:
#
# `Serving on port 5000...
#  Using the 'dep' visualizer`
#
# To view, go to the following address in your web browser:
#
# `http://127.0.0.1:5000/
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e0051f1287644f18ae650618ff7829bc-0" class="displacy" width="1410" height="307.0" direction="ltr" style="max-width: none; height: 307.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="217.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="217.0">
#     <tspan class="displacy-word" fill="currentColor" x="135">definitely</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="135">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="217.0">
# ...

# %%
# Certain entities are "special" though: names, places, 
# organizations, etc. These might be important for indexing
# purposes! They are known as named entities.

# Let's try a new sentence:
spacy_sen_2 = nlp("ACT UP was formed in March 1987 at the Lesbian and Gay Community Services Center in New York City. Larry Kramer was asked to speak as part of a rotating speaker series, and his well-attended speech focused on action to fight AIDS.")

# %%
# Let's print just the named entities. Programmatically,
# this process of finding and identifying named entities
# is called Named Entity Recognition (NER).
print(spacy_sen_2.ents)
# Out:
# (March 1987, Lesbian, Gay Community Services Center, New York City, Larry Kramer)

# %%
# As you can probably see, this process is difficult and isn't
# always perfect.

# Let's look at the specific lobels for these sentences.
for ent in spacy_sen_2.ents:
    print(ent.text + " : " + ent.label_)
# Out:
# March 1987 : DATE
# Lesbian : NORP
# Gay Community Services Center : ORG
# New York City : GPE
# Larry Kramer : PERSON

# %%
# What do these terms mean?
for ent in spacy_sen_2.ents:
    print(ent.text + " : " + ent.label_ + " : " + str(sp.explain(ent.label_)))
# Out:
# March 1987 : DATE : Absolute or relative dates or periods
# Lesbian : NORP : Nationalities or religious or political groups
# Gay Community Services Center : ORG : Companies, agencies, institutions, etc.
# New York City : GPE : Countries, cities, states
# Larry Kramer : PERSON : People, including fictional

# %%
# We can visualize these as follows:
displacy.render(spacy_sen_2, style='ent', jupyter=True)

# If you aren't using Jupyter, you'll need to use:
#
# `displacy.serve(spacy_sen_2, style='ent')
#
# Then you'll see the following:
#
# `Serving on port 5000...
#  Using the 'ent' visualizer`
#
# To view, go to the following address in your web browser:
#
# `http://127.0.0.1:5000/
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">ACT UP was formed in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 1987
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lesbian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gay Community Services Center
# ...

# %%
# NER is fast and easy to use to filter sentences for specific
# key information, but it makes a lot of assumptions.

# If we enter ~10,000 sentences, each with an average of 4
# named entities (based on this sentence). How many tags will be
# incorrectly labeled?

# Or, what if the document is created by a process which might
# not perfectly copy text from a source? For instance, what if we
# scan a PDF of someone's handwritten document and use OCR
# (Optical Character Recognition)?

# %%
# Here's a doc from the AIDS History Project, showcasing OCR
# versus corrected text:
ocr_text = """
"1 DEPARTMENT OF l?UBLIC HEALTH AIDS EDUCATION PLAN 83 - 84 PEOPLE WITH AIDS To provide AIDS-related information guidelines to all people Goal 1: diagnosed with AIDS. To universally distribute written information at the primary Obj. a: site of diagnosis and treatment, to include: medical aspects, lifestyle and health behaviors (stress, nutrition and substance abuse), epidemiology/etiology- (to clarify rey-ths and stereotypes), counseling and social service referrals, legal information (patients rights, informed consent, patient confidentiality). Obj. b: To provide available information and guidelines to people diagnosed with AIDS-like symptoms. Implementation: AIDS/KS will produce and distribute: 1 ) an ""AIDS Information Handbook"" (400 copies) will be produced by 12/15/83, 2) a companion volume ""Social 8ervices Resource Directory"" (400 copies) will be produced by 12/1/83. Grnli 2: To provide ongoing education and support activities for people with AIDS, their families and loved ones. Obj. a: To develop ongoing workshops and forums which will address: medical updates, sexual issues and concerns, nutrition and alternate therapies, and experiential bonding for people with AIDS and their loved ones. 1. Shanti and A1D8/YJ3 will sponsor a series of seminars (the first beginning 10/26/83) for people with AIDS, their ·friends and concerned individuals. 2. The AIDS Activity Office will assure continuing coordination . POPULA ~IONS AT RISK A. Self-identified Gay and Bisexual Males Goal 1 : rr_io develop and expand public media channels for education on AID8 for gay males. pgNbr=1 • 2 r AIDS/KS will develop public service announcements on AIDS Obj. a: education for distribution to radio stations by 1/84. DPH will develop and distribute two PSAs before 11/1/83. To develop and distribute pamphlets/posters at all levels in Goal 2: the gay male and bisexual community, (i.e., sensitive to age, ethnicity, lifestyles and locales). DPH will design and print 'AIDS Information for Gay and Obj. a: Bisexual Men' pamphlets for distribution throughout the city by 11/15/83. DPH will distribute updated AIDS information at regular Obj. b: intervals through 6/84. DPH will provide technical assistance to persons who wish to use various distribution methods, i.e. mass mailings. Obj. c: AIDS/KS will be responsible for: a. Publication and distribution of approximately 250 copies of an ~ducational Events Calendar which will be direct mailed twice monthly. b. Publication and distribution of 10,000 copies of the AIDS/KiS Foundation Newsletter (quarterly) providing current updates on the major medical, social and legislative aspects of AIDS. c. Community Education Program (Public Forums, Workshops, Seminars and/or Speaker's Bureau presentations). 2 presenta­ tions will be provided monthly for civic, professional social and community groups of high risk populations, with emphasis on Risk Reduction, Prevention and related health issues. d. Production and distribution of an attractive poster promoting known preventive practices, with compartments for dispensing risk reduction literature. 3CXJ copies will be produced and distributed in places where homosexually active men gather by 11/15/83. e. An .advertising campaign in gay and bisexual newspapers and magazines in the Bay Area will be developed. Ads will appear in 3 publications at least once per month. Public Service Ad space will be used whenever possible. f. Additional user friendly literature on risk reduction will be developed. 25,CXX) copies will be produced by March 1, 1984. g. Collaboration with existing providers in the development of special presentations and material development to reach sub­ groups of gay/bisexual men and other high risk groups. pgNbr=2 • 3 r To solicit and coordinate the support of community Goal 3: organizations around AIDS education for gay males. AIDS/KS will involve and educate the following community Obj. organizations to gain their endorsement and participation in the AIDS education plan by 12115/83: bath houses, sex clubs, GGBA, Tavern Guild, et al. To identify and locate covert homosexually active men, Goal 4: establish and implement appropriate methods for outreach on AIDS education, and evaluate effectiveness of this education. - Obj. DPH - AIDS Activity Office working with appropriate groups and individuals will assure that education programs for covert homosexually active men are developed by ·1/84. B. I. V. Drug Users and their Partners Goal 1 : To define the 1.V. drug user target group and establish channels for outreach on AIDS education. Nancy Presson will convene a group to research and determine the Obj. a: size and locations of the I.V. drug using community by 10/31/83. The above group will identify and contact opinion makers and other Obj. b: knowledgeable individuals, groups, and organizations to determine the best points for effective intervention in reaching the target groups by 10/31/83. Goal 2: To develop and distribute educational materials on AIDS for I.V. drug users and their partners. Obj. DPH-CSAS will develop and print 'AIDS Information for I.V. Drug Users and Their Partners' pamphlets for distribution by 11/15/83. C. The i:tai t ian Community Goal 1 : To define the at-risk Haitian community and establish channels for outreach on AIDS education. Obj. a: DPH - Madeline Ritchie will research and determine the size and location of the at-risk Haitian community by 11/1/83. Obj. b: DPH - Madeline Ritchie will identify and contact knowledgeable individuals and organizations (especially in New York and Florida) to determine the best strategies for intervention with the Haitian community at risk by 12/1 /83. pgNbr=3 4 To develop and distribute educational materials on AIDS for Goal 2: members of the Haitian community at risk. DPH and AIDS/KS will identify and utilize appropriate Obj. a: information network with access to the at-risk Haitian community to carry out AIDS education including designing and printing of appropriate pamphlets or posters by 1/84. D. Women To raise the visibility of women as involved with and at-risk Goal 1 : around AIDS. DPH/LGHSCC - Laurie Hauer and nat Norman will convene a committee Obj. a: of women to research and determine the size and location of the at-risk womens' community by 11/30/83. Obj. b: The committee will identify and contact knowledgable individuals and womens' and lesbian organizations to determine the best strategies and channels for intervention and dissemination of AIDS education by 12/15/83. ~o research and address the risks women face around Goal 2: contracting AIDS. Obj. a: The committee will develop specific plans and time lines to: 1) develop, design and print a pamphlet which deals specifically with women's issues (e.g. artificial insemination, women as partners of gay/bi-men, and I.V. drug users) for distribution. 2) research and write articles dealing with women's issues around AIDS for publication in womens and lesbian presses. 3) plan and implement forums and special events developed specifically to address women's issues around AIDS. ~. People in Jails and Institutions Goal 1: ~o define the at-risk populations and their locations in jails and other institutions. Obj. a: DPH - David tfannino will organize a committee which includes jail staff to research and define the extent and needs of the at-risk populations in jails/institutions by 11 /30/83. pgNbr=4 5 DPH - Forensic Services will contact knowledgeable individuals and Obj. b: I organizations to determine the best strategies for intervention with people in jails/institutions who are at risk by 12/15/83. To develop and expand staff training programs on AIDS Goal 2: education. DPH - Forensic Services will develop, implement and evaluate Obj. training programs on AIDS education for staff at the jails, SFGH prison wards by 1/15/83. Goal 7l· To develop and distribute educational materials and programs on AIDS for people in jails and other institutions. Obj. DPH will develop, design and print educational materials on AJDS for people in jails and other institutions, based on identified needs and selected interventions, by 1/15/83. F. Recipients of Blood Products Goal 1 : To provide health workers with current information on the risk of AIDS from transfusion of blood components and derivatives so that they may c~lTI.sel prospective blood recipients appropriately. Obj. a: Irwin Memorial Blood and the Bureau of Communicable Disease Control will remain aware of all cases of AIDS potentially related to transfusion via reports of cases to those offices and via reports to the CDC and the national blood bank organizations. Obj. b: The data and the consensus as to the risk of AIDS from tranfusion will be reported to health workers on a continuing basis via lectures, conferences and articles in local medical publications (e.g., the San Francisco Medical Society Bulletin). Goal 2: To provide educational materials about the risk of AIDS from transfusion to recipients or potential recipients of blood components or derivatives. Obj. a: ~hese materials will be developed by the Irwin Memorial Blood Bank with the help of the Bureau of Communicable Disease Control by November )0, 1983. Printed information leaflets will be distributed to all hospitals by December 20, 1983 with instructions for the hospitals to make them available to each patient (or his or her family) when transfusions may be needed. A notice that additional copies are available for physicians to distribute will be printed in the San ""Prancisco Medical Society Bulletin. pgNbr=5 6 SERVICE PROVIDERS & HEALTH CARE WORKERS To provide training on risk (real and imagined) and risk Goal I: reduction to target groups To train all health workers, with highest priorities Obj. a: according to those having contact with body fluids (excretions, coughing, sweating) and to students and interns - U.C., DPH, S""FGH. To coordinate training of other city and county employees, Obj. b: with highest priority to workers in the criminal justice system - DPH, LGHSCC -Obj. c: To coordinate training of non-city and county employees AIDS/KS will: 1 • Conduct professional trainingp and presentations which will occur at least once per month. 2. Plan, organize and sponsor an all-day Continuing Education program by 1/31/84 on Home Care for People With AIDS targeting RNs, Home Health Nurses, Hospice Staffs, Social Workers, Discharge Planners and other interested parties. 3. Develop a comprehensive packet of Infection Control Guidelines. 10J packets will be produced and made available for distribution by November 15, 198). 4. Collaborate and cooperate with other professional educational providers to develop standardized trainin~ programs and accompanying videotape and materials by 3/31/84. To update and distribute the ""Screening Protocal and Resource Obj. d: and Referral"" manual. DPH - Pat Norman 11/15/83. Obj. e: To stAndarize protocols for needlesticks and similar exposures - 11/15 - UCSF, S""FGH, Bureau of Disease Control. YOUNG ~EOPLEISCHOOLS Goal 1: To identify and document what exactly is being done for young people around AIDS education. Obj. a: DPH - Glen Margo will orgruiize a group to research and define the existing programs, interventions and needs for AIDS education for young people by 11/15/83. pgNbr=6 . .. 7 DPH - CSP - Sexual Minority Youth Program will identify and Obj. b: contact knowledgeable individuals and organizations to determine the best points for interventions for high risk youth and provide outreach to this population beginning 1/84. Goal 2: To develop and distribute educational materials on AIDS for yqung people. Obj. a: DPH and 8chool District will develop, design and print AIDS information for young people, pamphlets, and posters for distribution to all young people by 12/1/83. Obj. b: DPH, CSP, and School District will distribute AIDS information for young people through groups, organizations and other available service areas (e.g. hotlines, clinics, etc.). 'ro develop and expand staff training programs on AIDS Goal 3: education for young people. Obj. DPH and school district will provide training programs on AIDS for staff serving young people by 2/84. GENERAL POPULATION GoaJ_: To carry out a coordinated proactive education campaign focused on: 1 • Reducing fear 2. Increasing understanding of the disease 3. Include strategies and content to reduce homophobia, violence 4. Targeting to diverse popu1ations (culturally, raciaJ.ly sensitive) 5. Using common themes, messages and approaches to gain positive public recognition Obj. a: Mass media campaign for TV, radio and press using Public Service Announcements targeted at: (in priority sequence) 1 ) General population (White and Black sub-groups); 2) Spanish 3) Chinese; 4) Tagalog; and, 5) Vietnamese Emphasize high quality production. Provide adequate staffing to carry out the above and to respond quickly to inaccuracies or emerging situations - date dependent on funding, AIDS/KS pgNbr=7 8 Implementation - AIDS/KS will: L • 1. Develop and produce 25,000 ""user friendly"" attractive brochures for the general public by 12/15/83 and begin distribution 2. Translate, produce and distribute editions in Spanish, Tagalog and Chinese (at least 2500 copies in each language) of the general public brochure by 12/15/83. 3. Produce and place 200-300 internal and external placards and 3-5 MUN! METRO station display signs by 11/30/83. 4. Provide 3 educational presentations monthly targeting the general public (civic, professional, social and religious organizations). 5. Conduct public attitude and knowledge surveys. Results will be used to modify additional materials developed 6. Public Service Announcements (PSAs) for electronic media will be developed by distributed for the Bay Area by 3/84. Obj. b: Outreach to community and business groups - AIDS/KS 1. Speakers Bureau - centrally coordinated, using trained volunteers, identify and prioritize target groups, outreach, schedule and evaluate effectiveness - ongoing. 2. Hot Line - publicize more widely in all the above activities 3. Health Care Providers - a) use providers of service to educate non-risk populations regarding AIDS and, b) use providers, agencies, or organizations to distribute literature, posters - ongoing. D~H - AIDS Activity Office will monitor the above activities and time lines and provide feedback to the groups involved. pgNbr=8 "
"""

corrected_text = """
1 department of l? public health aids education plan 8384 people with aids to provide aids related information guidelines to all people goal 1: diagnosed with aids. to universally distribute written information at the primary ob. a: site of diagnosis and treatment, to include: medical aspects, lifestyle and health behavior stress, nutrition and substance abuse, epi etiology etiology to clarify re the and stereotyped, counsel ing and social service referral, legal information patients rights, informed consent, patient confidential ty. ob. b: to provide available information and guidelines to people diagnosed with aids like symptoms. implementation: aids es will produce and distribute: 1 an aids information handbook 400 copies will be produced by 121583,2 a companion volume social 8 services resource directory 400 copies will be produced by 12183. g rn li 2: to provide on going education and support activities for people with aids, their families and loved ones. ob. a: to develop on going workshops and forms which will address : medical u dates, sexual issues and concerns, nutrition and alternate ther pies, and ex erie tial bending for people with aids and their loved ones. 1. sh anti and a 1 d 8 ye 3 will sponsor a series of semi ars the first beginning 102683 for people with aids, their friends and concerned individuals. 2. the aids activity office will assure continuing coordination. popular ions at risk a. self identified gay and bisexual males goal 1: r rio develop and expand public media channels for education on aid 8 for gay males. 2 r aids es will develop public service announcements on aids ob. a: education for distribution to radio stations by 184. ph will develop and distribute two pass before 11183. to develop and distribute pamphlets posters at all levels in goal 2: the gay male and bisexual community, i. e., sensitive to age, ethnic ty, life styles and local es. ph will design and print aids information for gay and ob. a: bisexual men pamphlets for distribution throughout the city by 111583. ph will distribute updated aids information at regular ob. b: intervals through 684. ph will provide technical assistance to persons who wish to use various distribution methods, i. e. mass railings. ob. c: aids es will be responsible for: a. publication and distribution of approximately 250 copies of an educational events calendar which will be direct mailed twice monthly. b. publication and distribution of 10,000 copies of the aid s is foundation newsletter quarterly providing current u dates on the major medical, social and legislative aspects of aids. c. community education program public forms, workshops, semi ars and or speakers bureau presentations. 2 present a tions will be provided monthly for civic, professional social and community groups of high risk populations, with emphasis on risk reduction, prevention and related health issues. d. production and distribution of an attractive poster promoting known preventive practices, with compartments for dispensing risk reduction literature. 3 c xi copies will be produced and distributed in places where homosexual ly active men gather by 111583. e. an. advertising campaign in gay and bisexual newspapers and magazines in the bay area will be developed. aids will appear in 3 publications at least once per month. public service ad space will be used whenever possible. f. additional user friendly literature on risk reduction will be developed. 25, xx copies will be produced by march 1,1984. g. collaboration with existing providers in the development of special presentations and material development to reach sub groups of gay bisexual men and other high risk groups. 3 r to solicit and coordinate the support of community goal 3: organizations around aids education for gay males. aids es will involve and educate the following community ob. organizations to gain their endorsement and participation in the aids education plan by 1211583: bath houses, sex clubs, g ga, tavern guild, et al. to identify and locate covert homosexual ly active men, goal 4: establish and implement appropriate methods for out each on aids education, and evaluate effectiveness of this education. ob. ph aids activity office working with appropriate groups and individuals will assure that education programs for covert homosexual ly active men are developed by 184. b. i. v. drug users and their partners goal 1: to define the 1. v. drug user target group and establish channels for out each on aids education. nancy press on will convene a group to research and determine the ob. a: size and locations of the i. v. drug using community by 103183. the above group will identify and contact opinion makers and other ob. b: knowledge able individuals, groups, and organizations to determine the best points for effective intervention in reaching the target groups by 103183. goal 2: to develop and distribute educational materials on aids for i. v. drug users and their partners. ob. dphcsas will develop and print aids information for i. v. drug users and their partners pamphlets for distribution by 111583. c. the i: t i t i n community goal 1: to define the at risk haitian community and establish channels for out each on aids education. ob. a: ph madeline ritchie will research and determine the size and location of the at risk haitian community by 11183. ob. b: ph madeline ritchie will identify and contact knowledge able individuals and organizations especially in new york and florida to determine the best strategics for intervention with the haitian community at risk by 12183. 4 to develop and distribute educational materials on aids for goal 2: members of the haitian community at risk. ph and aids es will identify and utilize appropriate ob. a: information network with access to the at risk haitian community to carry out aids education including designing and printing of appropriate pamphlets or posters by 184. d. women to raise the visibility of women as involved with and at risk goal 1: around aids. dphlghscc laurie ha er and nat norman will convene a committee ob. a: of women to research and determine the size and location of the at risk women s community by 113083. ob. b: the committee will identify and contact know led able individuals and women s and lesbian organizations to determine the best strategics and channels for intervention and dissemination of aids education by 121583. o research and address the risks women face around goal 2: contracting aids. ob. a : the committee will develop specific plans and time lines to: 1 develop, design and print a pamphlet which deals specifically with women s issues e. g. artificial in semi nation, women as partners of gay men, and i. v. drug users for distribution. 2 research and write articles dealing with women s issues around aids for publication in women s and lesbian presses. 3 plan and implement forms and special events developed specifically to address women s issues around aids.. people in jails and institutions goal 1: o define the at risk populations and their locations in jails and other institutions. ob. a: ph david tea nino will organize a committee which includes jail staff to research and define the extent and needs of the at risk populations in jails institutions by 113083. 5 ph forensic services will contact knowledge able individuals and ob. b: i organizations to determine the best strategics for intervention with people in jails institutions who are at risk by 121583. to develop and expand staff training programs on aids goal 2: education. ph forensic services will develop, implement and evaluate ob. training programs on aids education for staff at the jails, sigh prison wards by 11583. goal 7 l to develop and distribute educational materials and programs on aids for people in jails and other institutions. ob. ph will develop, design and print educational materials on a jes for people in jails and other institutions, based on identified needs and selected intervention, by 11583. f. recipients of blood products goal 1: to provide health workers with current information on the risk of aids from transfusion of blood components and derivatives so that they may cut i. set prospective blood recipients appropriately. ob. a: irwin memorial blood and the bureau of communicable disease control will remain aware of all cases of aids potentially related to transfusion via reports of cases to those offices and via reports to the c c and the national blood bank organizations. ob. b: the data and the consensus as to the risk of aids from t ran fusion will be reported to health workers on a continuing basis via lectures, conferences and articles in local medical publications e. g., the san francisco medical society bulletin. goal 2: to provide educational materials about the risk of aids from transfusion to recipients or potential recipients of blood components or derivatives. ob. a: he se materials will be developed by the irwin memorial blood bank with the help of the bureau of communicable disease control by november 0,1983. printed information leaflets will be distributed to all hospitals by december 20,1983 with instructions for the hospitals to make them available to each patient or his or her family when transfusion may be needed. a notice that additional copies are available for physicians to distribute will be printed in the san francisco medical society bulletin. 6 service providers health care workers to provide training on risk real and imagined and risk goal i: reduction to target groups to train all health workers, with highest prior ties ob. a: according to those having contact with body fluids exc etions, coughing, sweating and to students and inter ns u. c., ph, sigh. to coordinate training of other city and county employees, ob. b: with highest priority to workers in the criminal justice system ph, l hs c ob. c: to coordinate training of non city and county employees aids es will: 1 conduct professional training p and presentations which will occur at least once per month. 2. plan, organize and sponsor an all day continuing education program by 13184 on home care for people with aids target ing r s, home health nurses, hospice staffs, social workers, discharge planters and other interested parties. 3. develop a comprehensive packet of infection control guidelines. 10 j packets will be produced and made available for distribution by november 15,198. 4. co labor te and cooperate with other professional educational providers to develop standardized train in programs and accompanying video tape and materials by 33184. to update and distribute the screening proto al and resource ob. d: and referral manual. ph pat norman 111583. ob. e: to stand rise protocols for needle sticks and similar exposures 1115 use, sigh, bureau of disease control. young people schools goal 1: to identify and document what exactly is being done for young people around aids education. ob. a: ph glen ma go will orgruiize a group to research and define the existing programs, intervention and needs for aids education for young people by 111583. ... 7 ph cap sexual minority youth program will identify and ob. b: contact knowledge able individuals and organizations to determine the best points for intervention for high risk youth and provide out each to this population beginning 184. goal 2: to develop and distribute educational materials on aids for young people. ob. a: ph and 8 school district will develop, design and print aids information for young people, pamphlets, and posters for distribution to all young people by 12183. ob. b: ph, cap, and school district will distribute aids information for young people through groups, organizations and other available service areas e. g. hot lines, clinics, etc.. ro develop and expand staff training programs on aids goal 3: education for young people. ob. ph and school district will provide training programs on aids for staff serving young people by 284. general population go ah: to carry out a co ordinated pr active education campaign focused on: 1 reducing fear 2. increasing understanding of the disease 3. include strategics and content to reduce homo habia, violence 4. target ing to diverse pope 1 nations cultur ally, racial. ly sensitive 5. using common themes, messages and approaches to gain positive public recognition ob. a: mass media campaign for tm, radio and press using public service announcements target ed at: in priority sequence 1 general population white and black sub groups; 2 spanish 3 chinese; 4 tagalog; and,5 vietnam se emphasize high quality production. provide adequate staff ing to carry out the above and to respond quickly to inaccuracies or emerging situations date dependent on funding, aids es 8 implementation aids es will: l 1. develop and produce 25,000 user friendly attractive brochure s for the general public by 121583 and begin distribution 2. translate, produce and distribute editions in spanish, tagalog and chinese at least 2500 copies in each language of the general public brochure by 121583. 3. produce and place 200300 internal and external placards and 35 m n! met ro station display signs by 113083. 4. provide 3 educational presentations monthly target ing the general public civic, professional, social and religious organizations. 5. conduct public attitude and knowledge surveys. results will be used to modify additional materials developed 6. public service announcements pass for electronic media will be developed by distributed for the bay area by 384. ob. b: out each to community and business groups aids es 1. speakers bureau centrally co ordinated, using trained volunteers, identify and prior time target groups, out each, schedule and evaluate effectiveness on going. 2. hot line public ze more widely in all the above activities 3. health care providers a use providers of service to educate non risk populations regarding aids and, b use providers, agencies, or organizations to distribute literature, posters on going. oh aids activity office will monitor the above activities and time lines and provide feedback to the groups involved.
"""

# %%
# Let's get the named entities from both.
ocr_spacy_text = nlp(ocr_text)
corrected_spacy_text = nlp(corrected_text)

print("OCR SPACY NAMED ENTITIES:")
print(ocr_spacy_text.ents)
print("\n") # Printing a newline.
print("CORRECTED SPACY NAMED ENTITIES:")
print(corrected_spacy_text.ents)
# Out:
# OCR SPACY NAMED ENTITIES:
# ...

# %%
# Or, if we want to visualize:
displacy.render(ocr_spacy_text, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"></br>&quot;
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  DEPARTMENT OF
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     l?UBLIC HEALTH AIDS EDUCATION
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# ...

# %%
# Versus the corrected text:
displacy.render(corrected_spacy_text, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  department of l? public health aids education plan
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8384
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people with aids to provide aids related information guidelines to all people goal
# ...

# %%
# How does this impact how we search documents?
# Which is easier to read as a human and which is easier
# to read as a computer?

# Well, let's try to search!

# %%
"""
SEARCHING TEXT PROGRAMMATICALLY
"""
# Out:
# '\nSEARCHING TEXT PROGRAMMATICALLY\n'

# %%
# First let's find a string in a list of strings.
string_to_search = "communities"

for token in tokenized_text:
    if token == string_to_search:
        print("Found it!")
# Out:
# Found it!

# %%
# Next, let's find a string in plaintext.
if string_to_search in essential_text:
    print("Found it!")
# Out:
# Found it!

# %%
# That was easy right? Well...
# What happens if we search "COMMUNITIES"?
string_to_search_2 = "COMMUNITIES"

if string_to_search_2 in essential_text:
    print("Found it! :)")
else:
    print("Not found! :(")
# Out:
# Not found! :(

# %%
# So capitalization doesn't match...
# What if we send the sentence to uppercase?
uppercase_essential_text = essential_text.upper()

if string_to_search_2 in uppercase_essential_text:
    print("Found it! :)")
else:
    print("Not found! :(")
# Out:
# Found it! :)

# %%
# But now the original string won't match...
# What if we send both the string to search and the
# string we're searching to lowercase?
lowercase_essential_text = essential_text.lower()

if string_to_search_2.lower() in lowercase_essential_text:
    print("Found it! :)")
else:
    print("Not found! :(")
# Out:
# Found it! :)

# %%
# But what if we want both?
# We can use the regular expressions package!
import re

if re.search(string_to_search_2, essential_text, re.IGNORECASE):
    print("Found it! :)")
else:
    print("Not found! :(")
# Out:
# Found it! :)

# %%
# What are regular expressions?
# A grouping of characters which define a search pattern.
# These can be simple, as above, or more complicated.
# (Usually, they are more complicated because language
# is complicated!)

# For instance, does "cat" appear in this sentence?
# "I'm not looking for something sophisticated."
# Let's see:
string_to_search_3 = 'cat'
less_essential_text = "I'm not looking for something sophisticated."

if re.search(string_to_search_3, less_essential_text, re.IGNORECASE):
    print("Found it! :)")
else:
    print("Not found! :(")
# Out:
# Found it! :)

# %%
# Uh-oh.
# Okay, well, can we make our search system better?
# Let's improve our regex (short for regular expression)!

# Regular expressions have all sorts of weird rules, and often
# feel like another programming language in and of themselves.
# Luckily, a number of sites provide "cheatsheets" and testing
# materials, so you can test before you run.
#
# I personally recommend: https://regexr.com/, but there
# are tons out there!

# %%
# For instance, let's try to make a regular expression that
# mimics "re.IGNORECASE" to start.

# Let's try to find "communities" or "COMMUNITIES" in the
# 'essential_text':
# "We definitely want to remember the way in which communities need agency over their own histories!"
#
# One way to do this is:
# (COMMUNITIES)|(communities)

# But that won't match "Communities" hmm...
#
# We could do this:
# [Cc][Oo][Mm][Mm][Uu][Nn][Ii][Tt][Ii][Ee][Ss]

# But that's a bit long...
#
# Let's do this instead. Click on the "flags" option
# at regexr.com. Select the 'case insensitive' option.
#
# Then we'll have this:
# (communities)/i

# %%
# But how do we do these in Python?

if re.search(r'(COMMUNITIES)|(communities)', essential_text):
    print("Found it! :)")
    
if re.search(r'[Cc][Oo][Mm][Mm][Uu][Nn][Ii][Tt][Ii][Ee][Ss]', essential_text):
    print("Found it! :)")
    
if re.search(r'(communities)', essential_text, flags=re.I):
    print("Found it! :)")
# Out:
# Found it! :)
# Found it! :)
# Found it! :)

# %%
# Let's return to our 'cat' example.
#
# There's a special flag, "\b" (backspace) which moves the
# cursor backwards on position (on the same 'row').
#
# With regular expressions, this functions as a 'word boundary'.
# This means that it attempts to differentiate between "word" and
# "non-word" characters.

# For instance:
if re.search(r"\b" + re.escape(string_to_search_3) + r"\b", less_essential_text, re.IGNORECASE):
    print("Found it! :P")
else:
    print("Not found! :O")
# Out:
# Not found! :O

# %%
# Finally, let's finish today attempting to search for a 
# "concept" rather than a word.
#
# For instance, notice what happens when we try to search
# 'community' in the essential text, even with our best regular
# expressions:

if re.search(r"\b" + re.escape('community') + r"\b", essential_text, re.IGNORECASE):
    print("Found it! :)")
else:
    print("Not found! :(")
# Out:
# Not found! :(

# %%
# What's a solution for this?
#
# What if we lemmatize?

# %%
# Some examples of lemmatization:
#
# rocks --> rock
# corpora --> corpus
# better --> good
#
# This'll help!

# %%
# Luckily, NLTK has a lemmatizer!
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# Let's test it!
print("communities" + ' : ' + lemmatizer.lemmatize("communities"))
# Out:
# communities : community

# %%
# Yay!
# Let's lemmatize our sentence (using our tokenizer!)
# and our search string.

lemmatized_search_string = lemmatizer.lemmatize('communities')
lemmatized_essential_text = [lemmatizer.lemmatize(word) for word in tokenized_text]
print(lemmatized_essential_text)
# Out:
# ['We', 'definitely', 'want', 'to', 'remember', 'the', 'way', 'in', 'which', 'community', 'need', 'agency', 'over', 'their', 'own', 'history', '!']

# %%
# Next we'll re-join our sentence.
lemmatized_essential_text_str = " ".join(lemmatized_essential_text)
print(lemmatized_essential_text_str)
# Out:
# We definitely want to remember the way in which community need agency over their own history !

# %%
# And now we'll search :)

if re.search(r"\b" + re.escape(lemmatized_search_string) + r"\b", lemmatized_essential_text_str, re.IGNORECASE):
    print("Found it! :)")
else:
    print("Not found! :(")
# Out:
# Found it! :)

# %%
# And that's the lesson! Yay! Great job!
